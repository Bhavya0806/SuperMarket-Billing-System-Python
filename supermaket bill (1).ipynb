# %%
#Super Market Billing System

print("The SuperMarket Bill")
name= input("enter your name:")
Phone_No = int(input("enter your phone number"))
print("-"*40)
subtotal=0
total_discount=0
repeat="y"
while repeat=="y":
    discount=0
    amount=0
    item_name= input("enter item name:")
    price= float (input("enter price:"))
    quantity= float (input("enter quantity:"))
    amount += price*quantity
    
    if amount>=500:
        discount= amount * 0.05 
    elif amount>=200:
        discount= amount * 0.02

    final_price= amount-discount
# Display Item Details
    print("Item added")
    print ("Item name:",item_name)
    print ("Quantity:", quantity)
    print ("Price:", price)
    print ("Amount:", amount)
    print ("Discount:", discount)
    print ("Final Price:", final_price)

    subtotal+= amount
    total_discount+= discount
    repeat= input("Do you want to add more items: (y/n)")
amount_payable = subtotal-total_discount    
# Final Bill

print("-"*40)
print("FINAL BILL")
print("-"*40)
print ("Sub Total:", subtotal)
print ("Total Discount:", total_discount)
print ("Amount Payable:", amount_payable)
print("-"*40)
print("THANK YOU FOR SHOPPING")
# Out:
# The SuperMarket Bill
# enter your name: bh
# enter your phone number 890
# ----------------------------------------
# enter item name: we
# enter price: 23
# enter quantity: 2
# Item added
# Item name: we
# Quantity: 2.0
# Price: 23.0
# Amount: 46.0
# Discount: 0
# Final Price: 46.0
# Do you want to add more items: (y/n) y
# enter item name: ui
# enter price: 60
# enter quantity: 4
# Item added
# Item name: ui
# Quantity: 4.0
# Price: 60.0
# Amount: 240.0
# Discount: 4.8
# Final Price: 235.2
# Do you want to add more items: (y/n) y
# enter item name: 70
# enter price: 8
# enter quantity: 70
# Item added
# Item name: 70
# Quantity: 70.0
# Price: 8.0
# Amount: 560.0
# Discount: 28.0
# Final Price: 532.0
# Do you want to add more items: (y/n) n
# ----------------------------------------
# FINAL BILL
# ----------------------------------------
# Sub Total: 846.0
# Total Discount: 32.8
# Amount Payable: 813.2
# ----------------------------------------
# THANK YOU FOR SHOPPING
